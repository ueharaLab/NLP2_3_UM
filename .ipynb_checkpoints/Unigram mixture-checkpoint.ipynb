# %% [markdown]
# # 混合カテゴリカル分布(Unigram Mixture)によるクラスタリング
# k-meansでは、秋田駅に関する2つのクラスタの違いが明確でなかったが、以下では、
#  - 秋田駅から観光地への交通・アクセスのクラスタ
#  - 秋田駅付近の名産品・名物料理のクラスタというように解釈できるようになっている。
#
# つまり、この分布モデルは、言語の分布をうまくとらえていると言える。
# （データセットは　create_dataset_forLDA.py で作成。）

# %%
import pandas as pd
import numpy as np
import em_algorithm

import codecs
import matplotlib
import matplotlib.pyplot as plt
import japanize_matplotlib
import pickle
import seaborn as sns


with open('dict_inv.pickle', 'rb') as f:
    dict_inv = pickle.load(f)
with open('dataset.pickle', 'rb') as f:
    all_reviews = pickle.load(f)


word_dic = {i:w for w, i in dict_inv.items()}
no_of_topics = 5
em_cat=em_algorithm.em_categorical(all_reviews,dict_inv,no_of_topics)
passes =20
theta,phi,qdk =em_cat.fit(passes)

for row in phi:
    w_dic = {word_dic[i]:np.round(val,3) for i,val in enumerate(row)}
    w_dic_sort = (sorted(w_dic.items(), reverse=True, key=lambda x:x[1]))
    print(w_dic_sort[:20])
# Out:
# no of step 1
# no of step 2
# no of step 3
# no of step 4
# no of step 5
# no of step 6
# no of step 7
# no of step 8
# no of step 9
# no of step 10
# no of step 11
# no of step 12
# no of step 13
# no of step 14
# no of step 15
# no of step 16
# no of step 17
# no of step 18
# no of step 19
# no of step 20
# [('秋田', 0.036), ('駅', 0.036), ('ホテル', 0.014), ('利用', 0.014), ('便利', 0.011), ('バス', 0.009), ('観光', 0.009), ('階', 0.009), ('土産', 0.008), ('施設', 0.008), ('レストラン', 0.007), ('空港', 0.007), ('部屋', 0.007), ('駐車', 0.007), ('号', 0.006), ('場所', 0.006), ('良い', 0.006), ('街', 0.006), ('駅前', 0.006), ('コンビニ', 0.005)]
# [('秋田', 0.032), ('味', 0.02), ('駅', 0.017), ('料理', 0.014), ('メニュー', 0.012), ('美味しい', 0.012), ('店内', 0.011), ('注文', 0.011), ('稲庭', 0.011), ('鶏', 0.011), ('美味しかっ', 0.01), ('ラーメン', 0.009), ('丼', 0.008), ('雰囲気', 0.008), ('利用', 0.007), ('名物', 0.007), ('有名', 0.007), ('種類', 0.007), ('角館', 0.007), ('麺', 0.007)]
# [('観光', 0.015), ('湖', 0.014), ('田沢湖', 0.014), ('秋田', 0.014), ('駐車', 0.012), ('像', 0.011), ('角館', 0.011), ('車', 0.011), ('桜', 0.01), ('温泉', 0.01), ('場所', 0.009), ('屋敷', 0.009), ('景色', 0.009), ('武家', 0.009), ('時期', 0.008), ('紅葉', 0.008), ('途中', 0.008), ('駅', 0.008), ('十和田湖', 0.007), ('展望', 0.007)]
# [('温泉', 0.028), ('部屋', 0.02), ('ホテル', 0.018), ('宿泊', 0.014), ('湯', 0.014), ('風呂', 0.014), ('利用', 0.013), ('秋田', 0.013), ('露天風呂', 0.013), ('食事', 0.012), ('宿', 0.011), ('朝食', 0.01), ('駅', 0.009), ('お湯', 0.008), ('良い', 0.008), ('料理', 0.007), ('浴場', 0.007), ('バス', 0.006), ('乳頭', 0.006), ('入浴', 0.006)]
# [('秋田', 0.026), ('駅', 0.02), ('展示', 0.015), ('館', 0.015), ('屋敷', 0.014), ('武家', 0.013), ('角館', 0.013), ('建物', 0.011), ('場所', 0.009), ('観光', 0.009), ('通り', 0.009), ('無料', 0.008), ('公園', 0.007), ('城', 0.007), ('時代', 0.007), ('歴史', 0.007), ('見学', 0.007), ('雰囲気', 0.007), ('佐竹', 0.006), ('千秋公園', 0.006)]

# %% [markdown]
# # k-meansのクラスタリング結果と比較する
# 秋田駅に関連する2つのクラスタの違いはクリアではない。

# %%
import pandas as pd
from sklearn.cluster import KMeans
import japanize_matplotlib
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
matplotlib.pyplot.rcParams['figure.figsize'] = (18.0, 10.0)
score_df = pd.read_csv("fortravel_bow.csv", encoding='ms932',index_col=0)

vec = KMeans(n_clusters=5)
pred_vec =vec.fit_predict(score_df.iloc[:,3:])
score_df["class"]=pred_vec
centers = vec.cluster_centers_

headers=score_df.columns.tolist()[3:-1]
import codecs
center_top20=[]
for c in centers:
   
    c_dic ={name:np.round(val,1) for name,val in zip(headers, c)}
    top_20 = sorted(c_dic.items(), key = lambda x : x[1],reverse=True)[:20]
    
    print(top_20)
    center_top20.append(top_20)
# Out:
# [('ホテル', 1.7), ('部屋', 0.9), ('利用', 0.6), ('朝食', 0.5), ('秋田', 0.5), ('駅', 0.5), ('宿泊', 0.4), ('ビジネス', 0.3), ('温泉', 0.3), ('風呂', 0.3), ('食事', 0.3), ('バイキング', 0.2), ('バス', 0.2), ('便利', 0.2), ('夕食', 0.2), ('客室', 0.2), ('快適', 0.2), ('料理', 0.2), ('浴場', 0.2), ('清潔', 0.2)]
# [('温泉', 2.6), ('湯', 1.2), ('宿', 0.5), ('露天風呂', 0.5), ('乳頭', 0.4), ('宿泊', 0.4), ('部屋', 0.4), ('風呂', 0.4), ('お湯', 0.3), ('利用', 0.3), ('日帰り', 0.3), ('泉', 0.3), ('入浴', 0.2), ('内湯', 0.2), ('料理', 0.2), ('施設', 0.2), ('旅館', 0.2), ('混浴', 0.2), ('温泉郷', 0.2), ('源泉', 0.2)]
# [('秋田', 0.2), ('バス', 0.1), ('メニュー', 0.1), ('ラーメン', 0.1), ('レストラン', 0.1), ('像', 0.1), ('公園', 0.1), ('利用', 0.1), ('十和田湖', 0.1), ('味', 0.1), ('土産', 0.1), ('地元', 0.1), ('場所', 0.1), ('多い', 0.1), ('宿泊', 0.1), ('展望', 0.1), ('展示', 0.1), ('山', 0.1), ('建物', 0.1), ('料理', 0.1)]
# [('屋敷', 1.6), ('武家', 1.4), ('角館', 1.2), ('桜', 0.7), ('通り', 0.6), ('観光', 0.3), ('場所', 0.2), ('展示', 0.2), ('建物', 0.2), ('時期', 0.2), ('秋田', 0.2), ('蔵', 0.2), ('見学', 0.2), ('館', 0.2), ('駅', 0.2), ('さくら', 0.1), ('カフェ', 0.1), ('ソメイヨシノ', 0.1), ('レストラン', 0.1), ('一番', 0.1)]
# [('秋田', 1.7), ('駅', 1.3), ('利用', 0.2), ('観光', 0.2), ('階', 0.2), ('館', 0.2), ('アクセス', 0.1), ('バス', 0.1), ('ビル', 0.1), ('ホテル', 0.1), ('ホーム', 0.1), ('メニュー', 0.1), ('ラーメン', 0.1), ('レストラン', 0.1), ('中心', 0.1), ('久保田', 0.1), ('佐竹', 0.1), ('便利', 0.1), ('側', 0.1), ('公園', 0.1)]

# %% [markdown]
# # Unigram MixtureによるクラスタでPCAプロットを色分けする
# 全てのクラスタが、意味ベクトルの方向に沿って散らばっている（k-meansでは、クラスタの１つが中央部分に固まっていた）

# %%
# %run mixture_unigram.py
# Out:
# no of step 1
# no of step 2
# no of step 3
# no of step 4
# no of step 5
# no of step 6
# no of step 7
# no of step 8
# no of step 9
# no of step 10
# [('秋田', 0.03), ('駅', 0.03), ('バス', 0.01), ('像', 0.01), ('列車', 0.01), ('利用', 0.01), ('十和田湖', 0.01), ('号', 0.01), ('国道', 0.01), ('土産', 0.01), ('場所', 0.01), ('展望', 0.01), ('施設', 0.01), ('日本海', 0.01), ('景色', 0.01), ('沿い', 0.01), ('温泉', 0.01), ('湖', 0.01), ('田沢湖', 0.01), ('男鹿半島', 0.01)]
# [('秋田', 0.04), ('駅', 0.02), ('メニュー', 0.01), ('ラーメン', 0.01), ('丼', 0.01), ('利用', 0.01), ('千秋公園', 0.01), ('名物', 0.01), ('味', 0.01), ('土産', 0.01), ('地元', 0.01), ('城', 0.01), ('場所', 0.01), ('店内', 0.01), ('徒歩', 0.01), ('料理', 0.01), ('有名', 0.01), ('横手', 0.01), ('注文', 0.01), ('稲庭', 0.01)]
# [('ホテル', 0.04), ('秋田', 0.03), ('部屋', 0.03), ('駅', 0.03), ('利用', 0.02), ('宿泊', 0.02), ('朝食', 0.02), ('コンビニ', 0.01), ('バイキング', 0.01), ('バス', 0.01), ('ビジネス', 0.01), ('フロント', 0.01), ('便利', 0.01), ('場所', 0.01), ('客室', 0.01), ('広く', 0.01), ('徒歩', 0.01), ('快適', 0.01), ('料理', 0.01), ('施設', 0.01)]
# [('温泉', 0.04), ('湯', 0.02), ('露天風呂', 0.02), ('風呂', 0.02), ('お湯', 0.01), ('バス', 0.01), ('ホテル', 0.01), ('乳頭', 0.01), ('入浴', 0.01), ('内湯', 0.01), ('利用', 0.01), ('夕食', 0.01), ('宿', 0.01), ('宿泊', 0.01), ('建物', 0.01), ('料理', 0.01), ('施設', 0.01), ('旅館', 0.01), ('日帰り', 0.01), ('泉', 0.01)]
# [('屋敷', 0.03), ('武家', 0.03), ('角館', 0.03), ('通り', 0.02), ('場所', 0.01), ('展示', 0.01), ('建物', 0.01), ('時代', 0.01), ('時期', 0.01), ('有名', 0.01), ('桜', 0.01), ('歴史', 0.01), ('満開', 0.01), ('無料', 0.01), ('秋田', 0.01), ('蔵', 0.01), ('見学', 0.01), ('観光', 0.01), ('車', 0.01), ('雰囲気', 0.01)]

# %% [markdown]
# # トピックモデルによるクラスタリング
# Unigram Mixtureと比較して、各クラスタ（トピック）は、相互の違いがはっきりする

# %%
# %run vbLDA.py
# Out:
# pass :  0
# pass :  1
# pass :  2
# pass :  3
# pass :  4
# pass :  5
# pass :  6
# pass :  7
# pass :  8
# pass :  9
# pass :  10
# pass :  11
# pass :  12
# pass :  13
# pass :  14
# pass :  15
# pass :  16
# pass :  17
# pass :  18
# pass :  19
# pass :  20
# pass :  21
# pass :  22
# pass :  23
# pass :  24
# pass :  25
# pass :  26
# pass :  27
# pass :  28
# pass :  29
# pass :  30
# pass :  31
# pass :  32
# pass :  33
# pass :  34
# pass :  35
# pass :  36
# pass :  37
